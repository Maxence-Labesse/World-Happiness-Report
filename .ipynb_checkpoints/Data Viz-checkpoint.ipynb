# %% [markdown]
# # Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# [Context](#Co)<br>
# [Import packages and data](#0)<br>
#
# 1. [**Happiness around the world in 2019**](#2019)<br>
#     [In which countries/regions of the world are people the happiest?](#Ha)<br>
#     [Which factors explain the differences in happiness](#Fa)<br>
#
#
# 2. [**Trends in happiness from 2015 to 2019**](#Ev)<br>
#     [In which countries/regions happiness has increased the most during this period?](#In)<br>
#     [Can we explain this growth?](#Ex)<br>
# </div>
# <hr>

# %% [markdown]
# <a name="Co"></a>
# # Context
#
# The **World Happiness Report** is a landmark survey of the state of global happiness from 2015 to 2019 according to 6 main factors:
# * economic production,
# * social support,
# * life expectancy, freedom,
# * absence of corruption,
# * and generosity
#
# ### Purposes of the project
# <ins> Data analysis: </ins>
# 1. Give a clear picture of happiness around the world in 2019
# 2. Analyse trends in happiness from 2015 to 2019
#
# <ins> Forecasting with Machine Learning</ins>(*)
# 1. How happy will countries be in 2020 ?
# 2. In which countries happiness will increase in 2020 ?
#
# (\*) *Although data don't contain related information, the global pandemic may have a tremendous impact on the results*
#
# You can find the whole presentation and information about the data in the **Project Presentation** notebook
#
# ### Workflow
# * Cleaning
# * EDA
# * **Data Visualization**
# * Preprocessing
# * Machine Learning
#
# Now we have a better knowledge about our data thanks to EDA, our objective is to use Data Visualization to answer the following questions:
#
# 1. Give a clear picture of happiness around the world in 2019
#     * In which countries/regions of the world are people the happiest?
#     * Which factors explain the differences in happiness ?
#
#
# 2. Analyse trends in happiness from 2015 to 2019
#     * In which countries/regions happiness has increased the most during this period?
#     * Can we explain this growth?

# %% [markdown]
# ------------
# ------------
# <a name="0"></a>
# # Import packages and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

from dataviz_utils import *
from Utils import print_title1

# %% [markdown]
# We import the cleaned data

# %%
df = pd.read_csv('data/data_clean_norm.csv')
print("data dimension:",df.shape)

# Happiness quartiles
df["happiness_level"]=pd.qcut(df["happiness_score"], 4, labels=["low", "low-mid", "top-mid", "top"])
l_level = ["top", "top-mid", "low-mid", "low"]

# years to string
df["year"] = df["year"].apply(lambda x: str(x))

# renaming some countries to match the map template
df['country'].replace({'Serbia': 'Republic of Serbia', 'Tanzania': 'United Republic of Tanzania',
                       'Congo (Brazzaville)': 'Republic of the Congo', 'Congo (Kinshasa)': 'Democratic Republic of the Congo',
                       'United States': 'United States of America'}, inplace=True)


# dataset containing data for 2019
df_2019 = df.loc[df["year"]=="2019"]

# dataset_containing data for 2015
df_2015 = df.loc[df["year"]=="2015"].copy()
df_2015.rename(columns=dict(zip(df.columns.tolist(),[col+"_2015" if col!="country" else col for col in df.columns.tolist()])), inplace=True)

# list containing the 6 factors names
l_factors = ['life_expectancy', 'gdp_per_capita', 'social_support', 
             'freedom','generosity', 'corruption_perception']
# Out:
# data dimension: (705, 11)

# %% [markdown]
# We prepare template data to build maps

# %%
# import world country boundaries
url = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/world_countries.json'
response = requests.get(url)
data = response.json()
  
# template to build map
world_geo = r'world_countries.json'

# %% [markdown]
# ------------
# ------------
# <a name="2019"></a>
# # 1. World Happiness

# %% [markdown]
# <a name="Ha"></a>
# ## In which countries/regions of the world are people the happiest?

# %%
country_map(df_2019, "country", "happiness_score", [45,0], 1.8, world_geo, "happiness", threshold_scale=None)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see on the map:
# * People feeling the happiest live in **North America (United States and Canada)**, **Australia and New Zealand**, and **North-Western Europe**. **Latin America** seems to have an overall good happiness perception too.
# * People feeling the lowest happy are in southern Africa
#
# The following graph - that displays the average happiness for regions in the world - confirms these observations.

# %%
bar_reg(df_2019,"region","happiness_score", "Average happiness and number of countries by region")

# %% [markdown]
# Although People living in **Sub-Saharan Africa** seems to have the lowest perception of happiness, this region represents several country and we can see on the map that happiness is very heterogeneous. **Central and Eastern Europe**, in which people feel moderately happy, seems to also represents many countries with large differences in happiness.
#
# Having a closer look at these countries may be interesting if you're bad at geography:

# %%
multiple_wordcloud_region(df_2019, ['Sub-Saharan Africa','Central and Eastern Europe'] ,"happiness_score", 100)

# %% [markdown]
# ### TOP 10 happiest country

# %%
display(df_2019[['country','region','happiness_rank']].sort_values(by="happiness_rank", ascending=True).set_index("happiness_rank").head(10))
# Out:
#                     country                     region
# happiness_rank
# 1                   Finland             Western Europe
# 2                   Denmark             Western Europe
# 3                    Norway             Western Europe
# 4                   Iceland             Western Europe
# 5               Netherlands             Western Europe
# 6               Switzerland             Western Europe
# 7                    Sweden             Western Europe
# 8               New Zealand  Australia and New Zealand
# 9                    Canada              North America
# 10                  Austria             Western Europe

# %% [markdown]
# The 7 happiest countries in the world in 2019 belong to **Northern** and **Western Europe**

# %% [markdown]
# ------------------------------
# <a name="Ha"></a>
# ## Which factors explain the differences in happiness ?

# %%
corr_matrix=df_2019[["happiness_score"]+l_factors].corr()

sns.heatmap(corr_matrix, annot = True)

# %% [markdown]
# The correlation matrix gives us an idea of the strength of the relationships between `happiness_score` and the different factors: With correlation >0.7, a relationship is considered as strong, while one with <0.3 is considerer as weak.
#
# `Happiness_score` seems to be strongly correlated to `gdp per capita`, `life expectancy`, `social supports` and, to a lesser extent, `freedom`. Let's try to explore the nature of these relationships

# %% [markdown]
# ### Life expectancy, gdp per capita, and social support

# %%
g=sns.pairplot(df_2019, y_vars="happiness_score", x_vars=['life_expectancy', 'social_support','gdp_per_capita'], hue="happiness_level",
            palette=['#F6EFF7', '#A6BDDB', '#3690C0', '#016450'], diag_kind = None)
g.fig.suptitle("Relationship between happiness and the 3 most correlated factors", y=1.08)
g._legend.set_title("Happiness")

# %% [markdown]
# Looking at the distribution of the countries in respect to happiness and the 3 most correlated factors, we can observe that these relationships are very linear: **the higher the factors, the higher the happiness**

# %% [markdown]
# ### Freedom

# %%
numeric_th_graph(df_2019, "happiness_level", "freedom", 60, "under")

# %% [markdown]
# Although it has an average correlation with `happiness` (0.56), a high `freedom` level seems to be a requirement to feel happy in a country. We can observe this on the graphs above, as **about 3 countries with a `freedom` perception <60 in 4 have a low/low-mid level of happiness**

# %% [markdown]
# ### Corruption perception

# %%
numeric_th_graph(df_2019, "happiness_level", "corruption_perception", 60, "over")

# %% [markdown]
# Despite a weak correlation with `happiness`, we can observe a very meaningful behavior here.
# On the left plot, we can see that if `coruption perception` is **higher than 60**, most of the countries are in the TOP25% happiest ones.
# Precisely, the chart on the right evidences that **almost 85% of the countries with `coruption perception` >60 belong to the TOP happiest countries**.

# %% [markdown]
# ### Generosity

# %%
g=sns.pairplot(df_2019, y_vars="happiness_score", x_vars=['generosity'], hue="happiness_level",
            palette=['#F6EFF7', '#A6BDDB', '#3690C0', '#016450'], diag_kind = None)
g.fig.suptitle("Relationship between happiness and generosity", y=1.08)
g._legend.set_title("Happiness")
g.fig.set_size_inches(10,4)

# %% [markdown]
# Like we saw in correlation matrix, `generosity` have a weak (0.1) relationships with `happiness`. There is no particular pattern to highlight here

# %% [markdown]
# ------------
# ------------
# <a name="Ev"></a>
# # 2. Trends in happiness from 2015 to 2019

# %% [markdown]
# <a name="In"></a>
# ## In which countries/regions happiness has increased during this period?

# %%
df_evol = pd.merge(df, df_2015, on="country", how="inner")

for col in ['happiness_score']+l_factors:
    df_evol['e_'+ col] = df_evol[col] - df_evol[col+"_2015"]
    
l_evol_factors = ['e_'+col for col in l_factors]

# %%
country_map(df_evol, "country", "e_happiness_score", [45, 0], 1.8, world_geo, "Happiness evolution from 2015 to 2019",
            threshold_scale=[-45, -10, 0, 5, 35])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can make several observation with the map:
# * **Latin America** Happiness has significantly decreased between 2015 and 2019 (-45 to -10)
# * **Estearn Asia**, **Western Europe** happiness has increased (+0 to +35)
# * **Western Africa** happiness has sharply increased (+5 to +35)

# %% [markdown]
# ----------
# <a name="Ex"></a>
# ## What does explain this growth?

# %%
corr_matrix=df_evol[["e_happiness_score"]+l_evol_factors].corr()

sns.heatmap(corr_matrix, annot = True)

# %% [markdown]
# The correlation matrix indicates that evolution of happiness is not correlated with the evolution of our factors from 2015 to 2019. Let's see if cross distribution can help us to find more information.

# %%
sns.pairplot(df_evol, y_vars="e_happiness_score", x_vars=l_evol_factors,  diag_kind = None)

# %% [markdown]
# There is no specific relationship to highlight between happiness evolution and factors evolution.
#
# According to the data we have, we assume that we can't explain the evolution of happiness between 2015 and 2019.

# %% [markdown]
# -------------------
# --------------------
# -----------------
#
# #
# Get countries with happiness evolution >5
# df_pos = df_evol[df_evol['evol']>5]
# evol_countries = df_pos['country'].tolist()
#
# #
# df_test = df_tot[df_tot["country"].isin(evol_countries)][l_factors+["year"]+["happiness_score","region"]]
#
# #
# df_test['region'].replace({"Southeastern Asia":"focus Asia","Southern Asia":"Southern Asia"}, inplace=True)
# df_tmp = df_test[["year"]+l_factors+["happiness_score","region"]].groupby(["year",'region'], axis=0).mean()
# df_tmp.reset_index(inplace=True)

# %% [markdown]
# for r in ['Western Europe', 'focus Asia', 'Sub-Saharan Africa']:
#     fig = plt.figure(figsize=(20,3))
#     j = 161
#     print_title1(r)
#     for f in l_factors:
#         plt.subplot(j)
#         dffff = df_tmp[df_tmp['region']==r][['year',f,"happiness_score"]]
#         plt.plot(dffff["year"], dffff[f], label="factor")
#         plt.plot(dffff["year"], dffff["happiness_score"], label="Happiness")
#         if j==161:
#             plt.legend(loc="upper left")
#         plt.title(f, y=-0.3)
#         j+=1
#
#     fig.suptitle("Evolution of happiness and factors in "+r+" region", fontsize=15)
#     plt.show()
